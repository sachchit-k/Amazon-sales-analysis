# %%
import pandas as pd
import os

# %%
all_data = pd.read_csv(r'D:\CONDA\1.PROJ\Pandas-Data-Science-Tasks-master\SalesAnalysis\Output\all_data.csv')
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# ##  Clean up the data!
# #### 1.drop rows with NaN

# %%
nan_df = all_data[all_data.isna().any(axis=1)]
nan_df.head()
# Out:
#      Order ID Product Quantity Ordered Price Each Order Date Purchase Address
# 355       NaN     NaN              NaN        NaN        NaN              NaN
# 734       NaN     NaN              NaN        NaN        NaN              NaN
# 1432      NaN     NaN              NaN        NaN        NaN              NaN
# 1552      NaN     NaN              NaN        NaN        NaN              NaN
# 1570      NaN     NaN              NaN        NaN        NaN              NaN

# %%
all_data = all_data.dropna(how='all')
all_data.head(10)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
# 5   176562        USB-C Charging Cable                1      11.95
# 6   176563  Bose SoundSport Headphones                1      99.99
# 7   176564        USB-C Charging Cable                1      11.95
# 8   176565          Macbook Pro Laptop                1       1700
# 9   176566            Wired Headphones                1      11.99
#
#        Order Date                        Purchase Address
# 0  04/19/19 08:46            917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30       682 Chestnut St, Boston, MA 02215
# ...

# %% [markdown]
# #### 2.finding 'or' and deleting it

# %%
temp_df=all_data[all_data['Order Date'].str[0:2] != 'Or']
temp_df.head(7)
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
# 5   176562        USB-C Charging Cable                1      11.95
# 6   176563  Bose SoundSport Headphones                1      99.99
#
#        Order Date                        Purchase Address
# 0  04/19/19 08:46            917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30       682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001
# 3  04/12/19 14:38    669 Spruce St, Los Angeles, CA 90001
# 4  04/30/19 09:27       333 8th St, Los Angeles, CA 90001
# 5  04/29/19 13:03  381 Wilson St, San Francisco, CA 94016
# ...

# %%
all_data=temp_df
all_data.head()
# Out:
#   Order ID                     Product Quantity Ordered Price Each  \
# 0   176558        USB-C Charging Cable                2      11.95
# 1   176559  Bose SoundSport Headphones                1      99.99
# 2   176560                Google Phone                1        600
# 3   176560            Wired Headphones                1      11.99
# 4   176561            Wired Headphones                1      11.99
#
#        Order Date                      Purchase Address
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001

# %% [markdown]
# #### 3.converting columns i correct format

# %%
all_data['Quantity Ordered']=pd.to_numeric(all_data['Quantity Ordered']) 
all_data['Price Each']=pd.to_numeric(all_data['Price Each'])

# %% [markdown]
# ## T1 --adding month column

# %%
all_data['Month'] = all_data['Order Date'].str[0:2]
all_data['Month'] = all_data['Month'].astype('int32')
all_data.tail(10)
# Out:
#        Order ID                   Product  Quantity Ordered  Price Each  \
# 186839   259349    AAA Batteries (4-pack)                 1        2.99
# 186840   259350              Google Phone                 1      600.00
# 186841   259350      USB-C Charging Cable                 1       11.95
# 186842   259351  Apple Airpods Headphones                 1      150.00
# 186843   259352      USB-C Charging Cable                 1       11.95
# 186844   259353    AAA Batteries (4-pack)                 3        2.99
# 186845   259354                    iPhone                 1      700.00
# 186846   259355                    iPhone                 1      700.00
# 186847   259356    34in Ultrawide Monitor                 1      379.99
# 186848   259357      USB-C Charging Cable                 1       11.95
#
#             Order Date                         Purchase Address  Month
# 186839  09/01/19 22:14           911 River St, Dallas, TX 75001      9
# ...

# %% [markdown]
# ## T2---add sales column

# %%
all_data['sales']=all_data['Quantity Ordered'].astype('int32')*all_data['Price Each'].astype('float64')
all_data.head(4)
# here we used as type for multiplying diff data types
#we can convert these rows in correct format as done above .3 or use astype for it
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   sales
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99

# %% [markdown]
# ## T3--Add city column

# %%
all_data.head(5)
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   sales
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99

# %%
#using .apply()
def get_city(address):
    return address.split(',')[1]
def get_state(address):
    return address.split(',')[2].split(' ')[1]

all_data['city']=all_data['Purchase Address'].apply(lambda x: f"{get_city(x)} ({get_state(x)})")
all_data.head(4)

def get_city(address):
    return address.split(',')[0]

all_data['customer address']=all_data['Purchase Address'].apply(lambda x:get_city(x))
all_data.head(4)
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
#
#                 city customer address
# 0        Dallas (TX)       917 1st St
# 1        Boston (MA)  682 Chestnut St
# 2   Los Angeles (CA)    669 Spruce St
# 3   Los Angeles (CA)    669 Spruce St

# %% [markdown]
# ### Q1=checking for best sales month

# %%
all_data.groupby('Month').sum()
# Out:
#        Quantity Ordered    Price Each         sales
# Month
# 1                 10903  1.811768e+06  1.822257e+06
# 2                 13449  2.188885e+06  2.202022e+06
# 3                 17005  2.791208e+06  2.807100e+06
# 4                 20558  3.367671e+06  3.390670e+06
# 5                 18667  3.135125e+06  3.152607e+06
# 6                 15253  2.562026e+06  2.577802e+06
# 7                 16072  2.632540e+06  2.647776e+06
# 8                 13448  2.230345e+06  2.244468e+06
# 9                 13109  2.084992e+06  2.097560e+06
# 10                22703  3.715555e+06  3.736727e+06
# 11                19798  3.180601e+06  3.199603e+06
# 12                28114  4.588415e+06  4.613443e+06

# %%
results=all_data.groupby('Month').sum()

# %%
import matplotlib.pyplot as plt
months= range(1,13)
plt.bar(months,results['sales'])
plt.xticks(months)
plt.ylabel('sales in USD')
plt.xlabel('Month number')
plt.show()

# %% [markdown]
# ### Q2=checkking which city has highest number of sales

# %%
city_sales=all_data.groupby('city').sum()

# %%
city_sales
# Out:
#                      Quantity Ordered    Price Each   Month         sales
# city
#  Atlanta (GA)                   16602  2.779908e+06  104794  2.795499e+06
#  Austin (TX)                    11153  1.809874e+06   69829  1.819582e+06
#  Boston (MA)                    22528  3.637410e+06  141112  3.661642e+06
#  Dallas (TX)                    16730  2.752628e+06  104620  2.767975e+06
#  Los Angeles (CA)               33289  5.421435e+06  208325  5.452571e+06
#  New York City (NY)             27932  4.635371e+06  175741  4.664317e+06
#  Portland (ME)                   2750  4.471893e+05   17144  4.497583e+05
#  Portland (OR)                  11303  1.860558e+06   70621  1.870732e+06
#  San Francisco (CA)             50239  8.211462e+06  315520  8.262204e+06
#  Seattle (WA)                   16553  2.733296e+06  104941  2.747755e+06

# %%
import matplotlib.pyplot as plt

cities=[city for city,df in all_data.groupby('city')]
plt.bar(cities,city_sales['sales'])
plt.xticks(cities,rotation='vertical',size=10)
plt.xlabel('city names')
plt.ylabel('sales')
plt.show()

# %% [markdown]
# ### Q3=checking customer sales

# %%
customer_sales=all_data.groupby('customer address').sum()

# %%
customer_sales
# Out:
#                    Quantity Ordered  Price Each  Month    sales
# customer address
# 1 11th St                         3     2411.95     22  2411.95
# 1 12th St                         4     1873.98     36  1873.98
# 1 13th St                         1       11.99      3    11.99
# 1 14th St                         8     1980.73     55  1996.52
# 1 1st St                          3       23.94     10    35.89
# ...                             ...         ...    ...      ...
# 999 Walnut St                     3     2094.94     19  2094.94
# 999 Washington St                 1      999.99      9   999.99
# 999 West St                       4      317.94     45   317.94
# 999 Willow St                     7      140.76     28   146.74
# 999 Wilson St                     5     1402.97     31  1402.97
#
# [46837 rows x 4 columns]

# %%
customer_sales.groupby(['customer address']).mean().sort_values('Quantity Ordered',ascending=False)
# Out:
#                   Quantity Ordered  Price Each  Month    sales
# customer address
# 661 Madison St                  24     3159.54     68  3203.51
# 60 10th St                      20     4053.83     83  4077.75
# 855 Highland St                 18      837.48     73   885.72
# 689 7th St                      18     1171.80     36  1210.23
# 992 Jackson St                  18     1499.54     80  1537.12
# ...                            ...         ...    ...      ...
# 819 Jefferson St                 1       14.95      1    14.95
# 527 7th St                       1       14.95      4    14.95
# 918 Pine St                      1     1700.00     10  1700.00
# 590 5th St                       1      600.00      3   600.00
# 219 Pine St                      1        2.99      6     2.99
#
# [46837 rows x 4 columns]

# %%
customer_sales.groupby(['customer address']).mean().sort_values('sales',ascending=False)
# Out:
#                   Quantity Ordered  Price Each  Month    sales
# customer address
# 844 12th St                      9     6513.93     56  6513.93
# 874 4th St                       8     6506.87     51  6506.87
# 480 Hill St                     10     6289.75     84  6289.75
# 986 7th St                      14     5975.82     94  5975.82
# 354 Main St                      7     5829.89     45  5829.89
# ...                            ...         ...    ...      ...
# 777 Sunset St                    1        2.99     10     2.99
# 268 Madison St                   1        2.99      8     2.99
# 532 9th St                       1        2.99      4     2.99
# 823 Madison St                   1        2.99      8     2.99
# 751 4th St                       1        2.99     10     2.99
#
# [46837 rows x 4 columns]

# %% [markdown]
# # all_data

# %%
all_data.head(50)
# Out:
#    Order ID                     Product  Quantity Ordered  Price Each  \
# 0    176558        USB-C Charging Cable                 2       11.95
# 1    176559  Bose SoundSport Headphones                 1       99.99
# 2    176560                Google Phone                 1      600.00
# 3    176560            Wired Headphones                 1       11.99
# 4    176561            Wired Headphones                 1       11.99
# 5    176562        USB-C Charging Cable                 1       11.95
# 6    176563  Bose SoundSport Headphones                 1       99.99
# 7    176564        USB-C Charging Cable                 1       11.95
# 8    176565          Macbook Pro Laptop                 1     1700.00
# 9    176566            Wired Headphones                 1       11.99
# 10   176567                Google Phone                 1      600.00
# 11   176568    Lightning Charging Cable                 1       14.95
# ...

# %% [markdown]
# #### Question 3: What time should we display advertisements to maximize likelihood of customer's buying product?

# %%
# Add hour column
all_data['Hour'] = pd.to_datetime(all_data['Order Date']).dt.hour
all_data['Minute'] = pd.to_datetime(all_data['Order Date']).dt.minute
all_data['Count'] = 1
all_data.head()
# Out:
#   Order ID                     Product  Quantity Ordered  Price Each  \
# 0   176558        USB-C Charging Cable                 2       11.95
# 1   176559  Bose SoundSport Headphones                 1       99.99
# 2   176560                Google Phone                 1      600.00
# 3   176560            Wired Headphones                 1       11.99
# 4   176561            Wired Headphones                 1       11.99
#
#        Order Date                      Purchase Address  Month   sales  \
# 0  04/19/19 08:46          917 1st St, Dallas, TX 75001      4   23.90
# 1  04/07/19 22:30     682 Chestnut St, Boston, MA 02215      4   99.99
# 2  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4  600.00
# 3  04/12/19 14:38  669 Spruce St, Los Angeles, CA 90001      4   11.99
# 4  04/30/19 09:27     333 8th St, Los Angeles, CA 90001      4   11.99
#
#                 city customer address  Hour  Minute  Count
# 0        Dallas (TX)       917 1st St     8      46      1
# ...

# %%
keys = [pair for pair, df in all_data.groupby(['Hour'])]

plt.plot(keys, all_data.groupby(['Hour']).count()['Count'])
plt.xticks(keys)
plt.grid()
plt.show()
